# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from pandas_profiling import ProfileReport

# %%
data_df = df = pd.read_csv('data.csv', delimiter='\t', quotechar='"')

# %%
data_df
# Out:
#         URG_EPISODIO  QUADRO  COD_PERG  HORA_ADMISSAO  COD_CAUSA  \
# 0           21000001      25        39            984        5.0
# 1           21000002      37       109           1100        5.0
# 2           21000004      32       131           1563       12.0
# 3           21000005      37       144           1642        5.0
# 4           21000007       7        43           2961       10.0
# ...              ...     ...       ...            ...        ...
# 204249      22167369      44        55          48837        5.0
# 204250      22167378      37        52          50086        5.0
# 204251      22167399      55       140          51985        5.0
# 204252      22167401      44        43          52041       12.0
# 204253      22167405      39        43          52250        1.0
#
#         COD_PROVENIENCIA  COD_PRIORIDADE  IDADE  COD_VIA_VERDE  SEXO  \
# 0                    NaN             2.0     58            NaN     1
# ...

# %%
data_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 204254 entries, 0 to 204253
# Data columns (total 14 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   URG_EPISODIO      204254 non-null  int64
#  1   QUADRO            204254 non-null  int64
#  2   COD_PERG          204254 non-null  int64
#  3   HORA_ADMISSAO     204254 non-null  int64
#  4   COD_CAUSA         204246 non-null  float64
#  5   COD_PROVENIENCIA  204221 non-null  float64
#  6   COD_PRIORIDADE    204239 non-null  float64
#  7   IDADE             204254 non-null  int64
#  8   COD_VIA_VERDE     7749 non-null    float64
#  9   SEXO              204254 non-null  int64
#  10  COD_CONCELHO      204254 non-null  int64
#  11  AFLUENCIA         204254 non-null  int64
#  12  LOS               204254 non-null  float64
#  13  Internamento      204254 non-null  int64
# dtypes: float64(5), int64(9)
# memory usage: 21.8 MB

# %%
data_df['QUADRO'].unique()
# Out:
# array([25, 37, 32,  7, 44, 21, 47, 43, 16, 28, 49, 40, 48, 27, 30, 26,  9,
#        24, 38,  8, 46, 45, 35, 51, 29, 10, 15, 39, 42, 14, 50, 23, 19, 55,
#        33,  2, 31,  1,  3, 20, 54, 22, 36,  4, 11, 17, 12, 41],
#       dtype=int64)

# %%
plt.figure(figsize=(10, 10))  # Adjust the figsize as per your preference
ax = sns.countplot(data=data_df, y='AFLUENCIA')

# Add labels on top of bars
for p in ax.patches:
    ax.annotate(format(p.get_width(), '.0f'), (p.get_x() + p.get_width(), p.get_y() + p.get_height() / 2.), ha='left', va='center')

plt.show()

# %%
len(data_df['Internamento'].unique())
# Out:
# 2

# %%
profile = ProfileReport(data_df)

# %%
profile.to_file('eda_report.html')
# Out:
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]
